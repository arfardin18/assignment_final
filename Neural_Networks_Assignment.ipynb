# %% [markdown]
# ## **Neural Networks:**

# %% [markdown]
# ### **Data Exploration:**

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score

# %%
data = pd.read_csv('Alphabets_data.csv')

# %%
data.head()
# Out:
#   letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  xybar  \
# 0      T     2     8      3       5      1     8    13      0      6      6
# 1      I     5    12      3       7      2    10     5      5      4     13
# 2      D     4    11      6       8      6    10     6      2      6     10
# 3      N     7    11      6       6      3     5     9      4      6      4
# 4      G     2     1      3       1      1     8     6      6      6      6
#
#    x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# 0      10       8      0       8      0       8
# 1       3       9      2       8      4      10
# 2       3       7      3       7      3       9
# 3       4      10      6      10      2       8
# 4       5       9      1       7      5      10

# %%
data.tail()
# Out:
#       letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  \
# 19995      D     2     2      3       3      2     7     7      7      6
# 19996      C     7    10      8       8      4     4     8      6      9
# 19997      T     6     9      6       7      5     6    11      3      7
# 19998      S     2     3      4       2      1     8     7      2      6
# 19999      A     4     9      6       6      2     9     5      3      1
#
#        xybar  x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# 19995      6       6       4      2       8      3       7
# 19996     12       9      13      2       9      3       7
# 19997     11       9       5      2      12      2       4
# 19998     10       6       8      1       9      5       8
# 19999      8       1       8      2       7      2       8

# %%
data.shape
# Out:
# (20000, 17)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   letter  20000 non-null  object
#  1   xbox    20000 non-null  int64
#  2   ybox    20000 non-null  int64
#  3   width   20000 non-null  int64
#  4   height  20000 non-null  int64
#  5   onpix   20000 non-null  int64
#  6   xbar    20000 non-null  int64
#  7   ybar    20000 non-null  int64
#  8   x2bar   20000 non-null  int64
#  9   y2bar   20000 non-null  int64
#  10  xybar   20000 non-null  int64
#  11  x2ybar  20000 non-null  int64
#  12  xy2bar  20000 non-null  int64
#  13  xedge   20000 non-null  int64
#  14  xedgey  20000 non-null  int64
#  15  yedge   20000 non-null  int64
#  16  yedgex  20000 non-null  int64
# dtypes: int64(16), object(1)
# memory usage: 2.6+ MB

# %%
data.describe()
# Out:
#                xbox          ybox         width       height         onpix  \
# count  20000.000000  20000.000000  20000.000000  20000.00000  20000.000000
# mean       4.023550      7.035500      5.121850      5.37245      3.505850
# std        1.913212      3.304555      2.014573      2.26139      2.190458
# min        0.000000      0.000000      0.000000      0.00000      0.000000
# 25%        3.000000      5.000000      4.000000      4.00000      2.000000
# 50%        4.000000      7.000000      5.000000      6.00000      3.000000
# 75%        5.000000      9.000000      6.000000      7.00000      5.000000
# max       15.000000     15.000000     15.000000     15.00000     15.000000
#
#                xbar          ybar         x2bar         y2bar         xybar  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       6.897600      7.500450      4.628600      5.178650      8.282050
# std        2.026035      2.325354      2.699968      2.380823      2.488475
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        6.000000      6.000000      3.000000      4.000000      7.000000
# 50%        7.000000      7.000000      4.000000      5.000000      8.000000
# 75%        8.000000      9.000000      6.000000      7.000000     10.000000
# max       15.000000     15.000000     15.000000     15.000000     15.000000
#
#             x2ybar        xy2bar         xedge        xedgey         yedge  \
# count  20000.00000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       6.45400      7.929000      3.046100      8.338850      3.691750
# std        2.63107      2.080619      2.332541      1.546722      2.567073
# min        0.00000      0.000000      0.000000      0.000000      0.000000
# 25%        5.00000      7.000000      1.000000      8.000000      2.000000
# 50%        6.00000      8.000000      3.000000      8.000000      3.000000
# 75%        8.00000      9.000000      4.000000      9.000000      5.000000
# max       15.00000     15.000000     15.000000     15.000000     15.000000
#
#             yedgex
# count  20000.00000
# mean       7.80120
# std        1.61747
# min        0.00000
# 25%        7.00000
# 50%        8.00000
# 75%        9.00000
# max       15.00000

# %%
#Check for Null Values
data.isnull().sum()
# Out:
# letter    0
# xbox      0
# ybox      0
# width     0
# height    0
# onpix     0
# xbar      0
# ybar      0
# x2bar     0
# y2bar     0
# xybar     0
# x2ybar    0
# xy2bar    0
# xedge     0
# xedgey    0
# yedge     0
# yedgex    0
# dtype: int64

# %% [markdown]
# ### **Data Preprocessing:**

# %%
# Encode the target label 'letter'
label_encoder = LabelEncoder()
data['letter'] = label_encoder.fit_transform(data['letter'])

# %%
# Normalize the feature values using MinMaxScaler
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data.drop('letter', axis=1))

# %%
# Create a new DataFrame with the scaled features and the encoded target
df = pd.DataFrame(scaled_data, columns=data.columns[1:])
df['letter'] = data['letter']

# %% [markdown]
# ### **Model Implementation:**

# %% [markdown]
# **Divide the dataset into training and test sets**

# %%
# Split the dataset into features and target
X = df.drop('letter', axis=1)
y = df['letter']

# Split the data into training (80%) and testing (20%) sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2, stratify=y)

# Check the shapes of the splits
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (16000, 16) (4000, 16) (16000,) (4000,)

# %%
# Determine the number of unique classes for the output layer
num_classes = len(y.unique())

# Convert the target variable to categorical (one-hot encoding)
y_train_categorical = to_categorical(y_train, num_classes)
y_test_categorical = to_categorical(y_test, num_classes)

# Construct the ANN model
model = Sequential()

# Input layer and first hidden layer with 32 neurons and ReLU activation
model.add(Dense(32, input_dim=X_train.shape[1], activation='relu'))

# Output layer with softmax activation (for multi-class classification)
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Display the model summary
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 32)                  │             544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 26)                  │             858 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,402 (5.48 KB)
#  Trainable params: 1,402 (5.48 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Train your model on the training set and then use it to make predictions on the test set**

# %%
# Train the model
history = model.fit(X_train, y_train_categorical, epochs=20, batch_size=30, validation_data=(X_test, y_test_categorical))
# Out:
# Epoch 1/20
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.1285 - loss: 3.1370 - val_accuracy: 0.3643 - val_loss: 2.5712
# Epoch 2/20
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4323 - loss: 2.3987 - val_accuracy: 0.5255 - val_loss: 2.0200
# Epoch 3/20
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5447 - loss: 1.9219 - val_accuracy: 0.5840 - val_loss: 1.7245
# Epoch 4/20
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5949 - loss: 1.6584 - val_accuracy: 0.5928 - val_loss: 1.5634
# Epoch 5/20
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6169 - loss: 1.5010 - val_accuracy: 0.6198 - val_loss: 1.4506
# Epoch 6/20
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6283 - loss: 1.4047 - val_accuracy: 0.6507 - val_loss: 1.3677
# Epoch 7/20
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6540 - loss: 1.3260 - val_accuracy: 0.6615 - val_loss: 1.3025
# Epoch 8/20
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6743 - loss: 1.2529 - val_accuracy: 0.6802 - val_loss: 1.2542
# Epoch 9/20
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6862 - loss: 1.2152 - val_accuracy: 0.6810 - val_loss: 1.2137
# Epoch 10/20
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6962 - loss: 1.1583 - val_accuracy: 0.6942 - val_loss: 1.1836
# Epoch 11/20
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7021 - loss: 1.1387 - val_accuracy: 0.7117 - val_loss: 1.1469
# Epoch 12/20
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7052 - loss: 1.1176 - val_accuracy: 0.7207 - val_loss: 1.1186
# Epoch 13/20
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7228 - loss: 1.0859 - val_accuracy: 0.7225 - val_loss: 1.0960
# Epoch 14/20
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7280 - loss: 1.0559 - val_accuracy: 0.7265 - val_loss: 1.0746
# Epoch 15/20
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7254 - loss: 1.0478 - val_accuracy: 0.7393 - val_loss: 1.0501
# Epoch 16/20
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7380 - loss: 1.0230 - val_accuracy: 0.7375 - val_loss: 1.0376
# Epoch 17/20
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7410 - loss: 1.0018 - val_accuracy: 0.7387 - val_loss: 1.0182
# Epoch 18/20
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7433 - loss: 0.9739 - val_accuracy: 0.7383 - val_loss: 1.0062
# Epoch 19/20
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7433 - loss: 0.9669 - val_accuracy: 0.7498 - val_loss: 0.9908
# Epoch 20/20
# 534/534 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7433 - loss: 0.9604 - val_accuracy: 0.7520 - val_loss: 0.9788

# %% [markdown]
# ### **Evaluation:**

# %%
# Evaluate the model on the test data
test_loss, test_accuracy = model.evaluate(X_test, y_test_categorical)

print(f'Test Loss: {test_loss}')
print(f'Test Accuracy: {test_accuracy}')

# Predict the classes on the test set
y_pred = model.predict(X_test)
y_pred_classes = y_pred.argmax(axis=1)

# Classification report
print(classification_report(y_test, y_pred_classes))

# Overall accuracy
print(f'Overall Accuracy: {accuracy_score(y_test, y_pred_classes)}')
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7487 - loss: 1.0012
# Test Loss: 0.9788363575935364
# Test Accuracy: 0.7519999742507935
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.87       158
#            1       0.61      0.83      0.70       153
#            2       0.81      0.78      0.79       147
#            3       0.68      0.65      0.67       161
#            4       0.63      0.82      0.71       154
#            5       0.79      0.71      0.75       155
#            6       0.67      0.59      0.63       155
#            7       0.76      0.50      0.61       147
#            8       0.92      0.81      0.86       151
#            9       0.90      0.81      0.85       149
#           10       0.66      0.71      0.69       148
#           11       0.88      0.74      0.80       152
#           12       0.88      0.87      0.88       158
#           13       0.80      0.81      0.81       157
#           14       0.66      0.74      0.70       151
#           15       0.80      0.78      0.79       161
#           16       0.72      0.59      0.65       157
#           17       0.62      0.76      0.69       151
#           18       0.46      0.47      0.46       149
#           19       0.85      0.75      0.80       159
#           20       0.85      0.88      0.86       163
#           21       0.77      0.90      0.83       153
#           22       0.86      0.90      0.88       150
#           23       0.71      0.78      0.74       157
#           24       0.79      0.76      0.78       157
#           25       0.77      0.71      0.74       147
#
#     accuracy                           0.75      4000
#    macro avg       0.76      0.75      0.75      4000
# weighted avg       0.76      0.75      0.75      4000
#
# Overall Accuracy: 0.752

# %%
precision = precision_score(y_test, y_pred_classes, average='weighted')
recall = recall_score(y_test, y_pred_classes, average='weighted')
f1 = f1_score(y_test, y_pred_classes, average='weighted')
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Precision: 0.7596439319901205
# Recall: 0.752
# F1-score: 0.7519320901915445
